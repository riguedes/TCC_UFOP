# %%
import os
import pandas as pd
import requests
import lyricsgenius
import csv

# Chamada de Requisição
api_key = "peEF0f6fbemhrR03PJBjFDGjdaQlkiAr4t1VUu7m-3LcaR7AY9hWTbBPcyEwZo6R"
genius = lyricsgenius.Genius(api_key)

# Busca do artista na API
artist = genius.search_artist("Beyoncé", max_songs=50)
# Out:
# Searching for songs by Beyoncé...
#
# Song 1: "Drunk in Love"
# Song 2: "Formation"
# Song 3: "Halo"
# Song 4: "Partition"
# Song 5: "If I Were a Boy"
# Song 6: "Mine"
# Song 7: "Hold Up"
# Song 8: "Flawless (Remix)"
# Song 9: "Sorry"
# Song 10: "All Night"
# Song 11: "Pray You Catch Me"
# Song 12: "***Flawless"
# Song 13: "Freedom"
# Song 14: "Don’t Hurt Yourself"
# Song 15: "BROWN SKIN GIRL"
# Song 16: "Irreplaceable"
# Song 17: "Listen"
# Song 18: "Blow"
# Song 19: "Pretty Hurts"
# Song 20: "Rocket"
# Song 21: "Sandcastles"
# Song 22: "6 Inch"
# Song 23: "7/11"
# Song 24: "Love Drought"
# Song 25: "Drunk in Love (Remix)"
# Song 26: "XO"
# Song 27: "Crazy in Love"
# Song 28: "Haunted"
# Song 29: "Daddy Lessons"
# Song 30: "Heaven"
# Song 31: "Countdown"
# Song 32: "HEATED"
# Song 33: "TEXAS HOLD ’EM"
# Song 34: "Love On Top"
# Song 35: "JOLENE"
# Song 36: "Jealous"
# Song 37: "BREAK MY SOUL"
# Song 38: "BLACK PARADE"
# Song 39: "Bow Down / I Been On"
# Song 40: "DAUGHTER"
# Song 41: "MOOD 4 EVA"
# Song 42: "Upgrade U"
# Song 43: "16 CARRIAGES"
# Song 44: "Forward"
# Song 45: "Me, Myself and I"
# Song 46: "Blue"
# Song 47: "Single Ladies (Put a Ring on It)"
# Song 48: "Lemonade Film (Script)"
# Song 49: "ALIEN SUPERSTAR"
# Song 50: "CUFF IT"
#
# Reached user-specified song limit (50).
# Done. Found 50 songs.

# %%
# Importando para um arquivo json
artist.save_lyrics()
# Out:
# Wrote Lyrics_Beyoncé.json.

# %%
# Acessando as chaves principais dos dados contidos no arquivo JSON
data = json.load(open("Lyrics_Beyoncé.json", "r"))
data.keys()
# Out:
# dict_keys(['alternate_names', 'api_path', 'description', 'facebook_name', 'header_image_url', 'id', 'image_url', 'instagram_name', 'is_meme_verified', 'is_verified', 'name', 'translation_artist', 'twitter_name', 'url', 'current_user_metadata', 'followers_count', 'description_annotation', 'user', 'songs'])

# %%
# Carregando dados em um dataframe e examinando os dados dentro de 'songs'
df = pd.DataFrame(data['songs'])
df.keys()
# Out:
# Index(['annotation_count', 'api_path', 'artist_names', 'full_title',
#        'header_image_thumbnail_url', 'header_image_url', 'id',
#        'lyrics_owner_id', 'lyrics_state', 'path', 'primary_artist_names',
#        'pyongs_count', 'relationships_index_url', 'release_date_components',
#        'release_date_for_display',
#        'release_date_with_abbreviated_month_for_display',
#        'song_art_image_thumbnail_url', 'song_art_image_url', 'stats', 'title',
#        'title_with_featured', 'url', 'featured_artists', 'primary_artist',
#        'primary_artists', 'apple_music_id', 'apple_music_player_url',
#        'description', 'embed_content', 'language', 'recording_location',
#        'release_date', 'current_user_metadata', 'song_art_primary_color',
#        'song_art_secondary_color', 'song_art_text_color', 'album',
#        'custom_performances', 'description_annotation',
#        'lyrics_marked_complete_by', 'lyrics_marked_staff_approved_by', 'media',
#        'producer_artists', 'song_relationships', 'translation_songs',
#        'verified_annotations_by', 'verified_contributors',
#        'verified_lyrics_by', 'writer_artists', 'artist', 'lyrics'],
#       dtype='object')

# %%
# Selecionando os dados úteis em um novo dataframe
df_oficial = df[['title', 'lyrics', 'release_date']].copy()

# Classificando as músicas pelo álbum
df_oficial['Album'] = df['album'].apply(lambda x: x.get('name') if isinstance(x, dict) else None)

# Reseta o índice, se necessário
df_oficial.reset_index(drop=True, inplace=True)

# Convertendo a coluna 'release_date' para o formato de data
df_oficial['release_date'] = pd.to_datetime(df_oficial['release_date'], errors='coerce')

# Extraindo apenas o ano da coluna 'release_date' para armazenar na 'release_year'
df_oficial['release_year'] = df_oficial['release_date'].dt.year

# Exibindo o dataframe resultante
df_oficial
# Out:
#                                             title  \
# 0                                        Dynamite
# 1                                          Butter
# 2                                       FAKE LOVE
# 3                     MIC Drop (Steve Aoki Remix)
# 4                             Permission to Dance
# 5                                 봄날 (Spring Day)
# 6                    전하지 못한 진심 (The Truth Untold)
# 7                                             DNA
# 8   MIC Drop (Steve Aoki Remix) [Desiigner Remix]
# 9                    피 땀 눈물 (Blood Sweat & Tears)
# 10                                     Magic Shop
# 11                                  Airplane pt.2
# 12                                       MIC Drop
# 13                                     땡 (Ddaeng)
# 14                     작은 것들을 위한 시 (Boy With Luv)
# 15             Butter (Megan Thee Stallion Remix)
# 16                                             ON
# 17                                   Crystal Snow
# 18                                       Anpanman
# 19                                고민보다 Go (Go Go)
# 20                                   Life Goes On
# 21                         낙원 (Paradise / Nakwon)
# 22                                     Best Of Me
# 23                                      Not Today
# 24                                      Love Maze
# 25                                    Outro: Tear
# 26                                         134340
# 27                                 Don’t Leave Me
# 28                                     Pied Piper
# 29                                         Let Go
# 30                                   보조개 (Dimple)
# 31                                       바다 (Sea)
# 32                               달려라 방탄 (Run BTS)
# 33                               상남자 (Boy In Luv)
# 34                                       I NEED U
# 35                                      Butterfly
# 36                    뱁새 (Silver Spoon / Baepsae)
# 37                                        So What
# 38                                    Born Singer
# 39                                     Black Swan
# 40                                      쩔어 (DOPE)
# 41           House of Cards (Full Length Edition)
# 42                                           IDOL
# 43                                      Heartbeat
# 44                                  No More Dream
# 45                                    Blue & Grey
# 46                                            RUN
# 47                                        Save ME
# 48                      불타오르네 (Burning Up) (Fire)
# 49       So Far Away (SUGA, Jin & Jung Kook Ver.)
#
#                                                lyrics release_date  \
# 0   312 ContributorsTranslationsفارسیالعربيةУкраїн...   2020-08-21
# 1   246 ContributorsTranslationsTürkçeไทย (Thai)Es...   2021-05-21
# 2   130 ContributorsTranslationsEnglishRomanizatio...   2018-05-18
# 3   100 ContributorsTranslationsRomanizationEnglis...   2017-11-24
# 4   121 ContributorsTranslationsTürkçeEspañolРусск...   2021-07-09
# 5   101 ContributorsTranslationsRomanizationEnglis...   2017-02-13
# 6   91 ContributorsTranslationsTürkçeEnglishRomani...   2018-05-18
# 7   98 ContributorsTranslationsRomanizationEnglish...   2017-09-18
# 8   87 ContributorsTranslationsRomanizationMIC Dro...   2017-11-24
# 9   77 ContributorsTranslationsRomanizationDanskEn...   2016-10-10
# 10  56 ContributorsTranslationsazərbaycanEnglishEs...   2018-05-18
# 11  69 ContributorsTranslationsTürkçeDeutschفارسیE...   2018-05-18
# 12  62 ContributorsTranslationsفارسیEnglish繁體中文 (T...   2017-09-18
# 13  49 ContributorsTranslationsEnglishRomanization...   2018-06-10
# 14  73 ContributorsTranslationsBahasa IndonesiaУкр...   2019-04-12
# 15  58 ContributorsTranslationsTürkçeРусский (Russ...   2021-08-27
# 16  59 ContributorsTranslationsRomanizationEnglish...   2020-02-21
# 17  44 ContributorsTranslationsفارسیRomanizationEn...   2017-12-06
# 18  59 ContributorsTranslationsazərbaycanفارسیRoma...   2018-05-18
# 19  43 ContributorsTranslationsفارسیRomanizationEn...   2017-09-18
# 20  47 ContributorsTranslationsRomanizationEnglish...   2020-11-20
# 21  48 ContributorsTranslationsDeutschفارسیРусский...   2018-05-18
# 22  33 ContributorsTranslationsفارسیRomanizationEs...   2017-09-18
# 23  61 ContributorsTranslationsFrançaisEnglishRoma...   2017-02-14
# 24  31 ContributorsTranslationsPortuguêsDeutschفار...   2018-05-18
# 25  51 ContributorsTranslationsRomanizationEnglish...   2018-05-18
# 26  50 ContributorsTranslationsRomanizationEnglish...   2018-05-18
# 27  47 ContributorsTranslationsفارسیRomanizationEn...   2018-04-03
# 28  48 ContributorsTranslationsČeskyРусский (Russi...   2017-09-18
# 29  54 ContributorsTranslationsفارسیEnglishRomaniz...   2018-04-04
# 30  32 ContributorsTranslationsItalianoTürkçeEspañ...   2017-09-18
# 31  37 ContributorsTranslationsفارسیქართულიEnglish...   2017-09-18
# 32  28 ContributorsTranslationsItalianoУкраїнськаT...   2022-06-10
# 33  36 ContributorsTranslationsItalianoРусский (Ru...   2014-02-11
# 34  36 ContributorsTranslationsItalianoУкраїнськаE...   2015-04-29
# 35  32 ContributorsTranslationsItalianoTürkçeEngli...   2015-11-30
# 36  33 ContributorsTranslationsItalianoEnglishRoma...   2015-11-30
# 37  34 ContributorsTranslationsEspañolفارسیEnglish...   2018-05-18
# 38  35 ContributorsTranslationsRomanizationEnglish...   2013-07-11
# 39  59 ContributorsTranslationsRomanizationEnglish...   2020-01-17
# 40  36 ContributorsTranslationsItalianoFrançaisRom...   2015-06-23
# 41  34 ContributorsTranslationsFrançaisEnglishRoma...   2016-05-02
# 42  54 ContributorsTranslationsفارسیУкраїнськаEspa...   2018-08-24
# 43  32 ContributorsTranslationsDeutschTürkçeRomani...   2019-06-28
# 44  40 ContributorsTranslationsItalianoفارسیMagyar...   2014-06-04
# 45  31 ContributorsTranslationsRomanizationEnglish...   2020-11-20
# 46  34 ContributorsTranslationsItalianoTürkçeУкраї...   2015-11-29
# 47  44 ContributorsTranslationsPortuguêsFrançaisفا...   2016-05-02
# 48  47 ContributorsTranslationsItalianoहिन्दी (Hin...   2016-05-02
# 49  12 ContributorsSo Far Away (SUGA, Jin & Jung K...   2017-06-14
#
#                                                 Album  release_year
# 0                                               Proof          2020
# 1                                               Proof          2021
# 2                                               Proof          2018
# 3                                                None          2017
# 4               Butter / Permission to Dance - Single          2021
# 5                                               Proof          2017
# 6                            LOVE YOURSELF 結 ‘Answer’          2018
# 7                                               Proof          2017
# 8               NOW That’s What I Call Music! 65 [US]          2017
# 9                                               Proof          2016
# 10                           LOVE YOURSELF 結 ‘Answer’          2018
# 11                           LOVE YOURSELF 結 ‘Answer’          2018
# 12                           LOVE YOURSELF 結 ‘Answer’          2017
# 13                                SoundCloud Releases          2018
# 14                                              Proof          2019
# 15                                               None          2021
# 16                                              Proof          2020
# 17                                      BTS, THE BEST          2017
# 18                           LOVE YOURSELF 結 ‘Answer’          2018
# 19                           LOVE YOURSELF 結 ‘Answer’          2017
# 20                                              Proof          2020
# 21                             LOVE YOURSELF 轉 ‘Tear’          2018
# 22                           LOVE YOURSELF 結 ‘Answer’          2017
# 23                               You Never Walk Alone          2017
# 24                             LOVE YOURSELF 轉 ‘Tear’          2018
# 25                             LOVE YOURSELF 轉 ‘Tear’          2018
# 26                             LOVE YOURSELF 轉 ‘Tear’          2018
# 27                                      BTS, THE BEST          2018
# 28                              LOVE YOURSELF 承 ‘Her’          2017
# 29                                      BTS, THE BEST          2018
# 30                                              Proof          2017
# 31                              LOVE YOURSELF 承 ‘Her’          2017
# 32                                              Proof          2022
# 33                                              Proof          2014
# 34                                              Proof          2015
# 35  화양연화 Young Forever (The Most Beautiful Moment ...          2015
# 36  화양연화 Young Forever (The Most Beautiful Moment ...          2015
# 37                             LOVE YOURSELF 轉 ‘Tear’          2018
# 38                                SoundCloud Releases          2013
# 39                                 MAP OF THE SOUL: 7          2020
# 40  화양연화 Young Forever (The Most Beautiful Moment ...          2015
# 41  화양연화 Young Forever (The Most Beautiful Moment ...          2016
# 42                                              Proof          2018
# 43                    BTS WORLD (Original Soundtrack)          2019
# 44                                              Proof          2014
# 45                                                 BE          2020
# 46                                              Proof          2015
# 47  화양연화 Young Forever (The Most Beautiful Moment ...          2016
# 48                                              Proof          2016
# 49                                SoundCloud Releases          2017

# %%
import nltk
from nltk.corpus import stopwords
import re

# Define uma função para remover stopwords de um texto
def remove_stopwords(text):
    # Separa o texto em uma lista de palavras
    text = text.split(' ')
    # Filtra a lista, mantendo apenas as palavras que não estão na lista de stopwords em inglês
    text = [x for x in text if x not in stopwords.words('english')]
    # Junta a lista de palavras filtradas em uma única string e a retorna
    return ' '.join(text)

# Aplica a função de remoção de stopwords em cada linha da coluna 'lyrics' do dataframe
df_oficial.loc[:, 'lyrics'] = df_oficial.loc[:, 'lyrics'].apply(lambda x: remove_stopwords(x))

# Define uma função para remover pontuação do texto
def remove_ponctuation(text):
    # Usa uma expressão regular para manter apenas letras (maiúsculas e minúsculas) e junta as palavras em uma string
    return " ".join(re.findall("[a-zA-Z]+", text))

# Aplica a função de remoção de pontuação em cada linha da coluna 'lyrics' do dataframe
df_oficial.loc[:, 'lyrics'] = df_oficial.loc[:, 'lyrics'].apply(lambda x: remove_ponctuation(x))

# Define uma função para remover palavras com menos de 3 caracteres do texto
def remove_words_with_less_3(text):
    # Separa o texto em uma lista de palavras
    text = text.split(' ')
    # Filtra a lista, mantendo apenas as palavras com mais de 3 caracteres
    text = [x for x in text if len(x) > 3]
    # Junta a lista de palavras filtradas em uma única string e a retorna
    return ' '.join(text)

# Aplica a função de remoção de palavras curtas em cada linha da coluna 'lyrics' do dataframe
df_oficial.loc[:, 'lyrics'] = df_oficial.loc[:, 'lyrics'].apply(lambda x: remove_words_with_less_3(x))

# Converte todo o texto em letras minúsculas em cada linha da coluna 'lyrics' do dataframe
df_oficial.loc[:, 'lyrics'] = df_oficial.loc[:, 'lyrics'].apply(lambda x: x.lower())

# Cria uma nova coluna 'Word Count' no dataframe que conta o número de palavras em cada linha da coluna 'lyrics'
df_oficial['Word Count'] = df_oficial['lyrics'].apply(lambda x: len(x.split(' ')))

# Função para remover as palavras indesejadas
def remove_unwanted_words(text):
    words_to_remove = ["embed", "intro", "verse", "chorus", "outro", "instrumental"]
    pattern = r'\b(?:' + '|'.join(words_to_remove) + r')\b'
    return re.sub(pattern, '', text, flags=re.IGNORECASE)

# Aplicar a função na coluna de letras
df_oficial["lyrics"] = df_oficial["lyrics"].apply(remove_unwanted_words)

# Salvar o CSV atualizado
df_oficial.to_csv("BTS.csv", index=False)

# %%
# Importando bibliotecas de manipulação e análise de dados
import pandas as pd  # Usado para manipulação de tabelas e dataframes
import numpy as np   # Usado para operações matemáticas e arrays numéricos

# Biblioteca de NLP (Processamento de Linguagem Natural)
from nltk.tokenize import word_tokenize  # Quebra textos em palavras (tokens)

# Baixando recursos da biblioteca NLTK
import nltk
nltk.download('punkt_tab')  # Tokenizador de pontuação/tabulação
nltk.download('vader_lexicon')  # Léxico para análise de sentimentos com VADER (análise de sentimentos)
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\Ryan\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\Ryan\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
# Leitura do Arquivo
df_oficial=pd.read_csv("BTS.csv")

# Remove a coluna 'release_date'
df_oficial = df_oficial.drop(columns=['release_date'])

# Visualização do Dataframe
df_oficial
# Out:
#                                             title  \
# 0                                        Dynamite
# 1                                          Butter
# 2                                       FAKE LOVE
# 3                     MIC Drop (Steve Aoki Remix)
# 4                             Permission to Dance
# 5                                 봄날 (Spring Day)
# 6                    전하지 못한 진심 (The Truth Untold)
# 7                                             DNA
# 8   MIC Drop (Steve Aoki Remix) [Desiigner Remix]
# 9                    피 땀 눈물 (Blood Sweat & Tears)
# 10                                     Magic Shop
# 11                                  Airplane pt.2
# 12                                       MIC Drop
# 13                                     땡 (Ddaeng)
# 14                     작은 것들을 위한 시 (Boy With Luv)
# 15             Butter (Megan Thee Stallion Remix)
# 16                                             ON
# 17                                   Crystal Snow
# 18                                       Anpanman
# 19                                고민보다 Go (Go Go)
# 20                                   Life Goes On
# 21                         낙원 (Paradise / Nakwon)
# 22                                     Best Of Me
# 23                                      Not Today
# 24                                      Love Maze
# 25                                    Outro: Tear
# 26                                         134340
# 27                                 Don’t Leave Me
# 28                                     Pied Piper
# 29                                         Let Go
# 30                                   보조개 (Dimple)
# 31                                       바다 (Sea)
# 32                               달려라 방탄 (Run BTS)
# 33                               상남자 (Boy In Luv)
# 34                                       I NEED U
# 35                                      Butterfly
# 36                    뱁새 (Silver Spoon / Baepsae)
# 37                                        So What
# 38                                    Born Singer
# 39                                     Black Swan
# 40                                      쩔어 (DOPE)
# 41           House of Cards (Full Length Edition)
# 42                                           IDOL
# 43                                      Heartbeat
# 44                                  No More Dream
# 45                                    Blue & Grey
# 46                                            RUN
# 47                                        Save ME
# 48                      불타오르네 (Burning Up) (Fire)
# 49       So Far Away (SUGA, Jin & Jung Kook Ver.)
#
#                                                lyrics  \
# 0   contributorstranslations eespa russian portugu...
# 1   contributorstranslationst thai espa olportugu ...
# 2   contributorstranslationsenglishromanizationshq...
# 3   contributorstranslationsromanizationenglish fr...
# 4   contributorstranslationst eespa russian portug...
# 5   contributorstranslationsromanizationenglishfra...
# 6   contributorstranslationst eenglishromanization...
# 7   contributorstranslationsromanizationenglish ko...
# 8   contributorstranslationsromanizationmic drop s...
# 9   contributorstranslationsromanizationdanskengli...
# 10  contributorstranslationsaz rbaycanenglishespa ...
# 11  contributorstranslationst edeutsch espa olroma...
# 12  contributorstranslations english traditional c...
# 13  contributorstranslationsenglishromanization dd...
# 14  contributorstranslationsbahasa indonesia eespa...
# 15  contributorstranslationst russian portugu japa...
# 16  contributorstranslationsromanizationenglish hi...
# 17  contributorstranslations romanizationenglishcr...
# 18  contributorstranslationsaz rbaycan romanizatio...
# 19  contributorstranslations romanizationenglish l...
# 20  contributorstranslationsromanizationenglish rb...
# 21  contributorstranslationsdeutsch russian romani...
# 22  contributorstranslations romanizationespa olen...
# 23  contributorstranslationsfran aisenglishromaniz...
# 24  contributorstranslationsportugu sdeutsch russi...
# 25  contributorstranslationsromanizationenglishfra...
# 26  contributorstranslationsromanizationenglishesp...
# 27  contributorstranslations romanizationenglishdo...
# 28  contributorstranslations esky russian eespa en...
# 29  contributorstranslations englishromanizationle...
# 30  contributorstranslationsitalianot eespa englis...
# 31  contributorstranslations englishromanization l...
# 32  contributorstranslationsitaliano thai espa olp...
# 33  contributorstranslationsitaliano russian espa ...
# 34  contributorstranslationsitaliano espa hindi fr...
# 35  contributorstranslationsitalianot eenglishroma...
# 36  contributorstranslationsitalianoenglishromaniz...
# 37  contributorstranslationsespa englishromanizati...
# 38  contributorstranslationsromanizationenglishesp...
# 39  contributorstranslationsromanizationenglishesp...
# 40  contributorstranslationsitalianofran aisromani...
# 41  contributorstranslationsfran aisenglishromaniz...
# 42  contributorstranslations espa russian portugu ...
# 43  contributorstranslationsdeutscht eromanization...
# 44  contributorstranslationsitaliano magyardeutsch...
# 45  contributorstranslationsromanizationenglishesp...
# 46  contributorstranslationsitalianot espa olfran ...
# 47  contributorstranslationsportugu sfran englishs...
# 48  contributorstranslationsitaliano hindi espa ol...
# 49  contributorsso away suga jung kook lyrics away...
#
#                                                 Album  release_year  \
# 0                                               Proof          2020
# 1                                               Proof          2021
# 2                                               Proof          2018
# 3                                                 NaN          2017
# 4               Butter / Permission to Dance - Single          2021
# 5                                               Proof          2017
# 6                            LOVE YOURSELF 結 ‘Answer’          2018
# 7                                               Proof          2017
# 8               NOW That’s What I Call Music! 65 [US]          2017
# 9                                               Proof          2016
# 10                           LOVE YOURSELF 結 ‘Answer’          2018
# 11                           LOVE YOURSELF 結 ‘Answer’          2018
# 12                           LOVE YOURSELF 結 ‘Answer’          2017
# 13                                SoundCloud Releases          2018
# 14                                              Proof          2019
# 15                                                NaN          2021
# 16                                              Proof          2020
# 17                                      BTS, THE BEST          2017
# 18                           LOVE YOURSELF 結 ‘Answer’          2018
# 19                           LOVE YOURSELF 結 ‘Answer’          2017
# 20                                              Proof          2020
# 21                             LOVE YOURSELF 轉 ‘Tear’          2018
# 22                           LOVE YOURSELF 結 ‘Answer’          2017
# 23                               You Never Walk Alone          2017
# 24                             LOVE YOURSELF 轉 ‘Tear’          2018
# 25                             LOVE YOURSELF 轉 ‘Tear’          2018
# 26                             LOVE YOURSELF 轉 ‘Tear’          2018
# 27                                      BTS, THE BEST          2018
# 28                              LOVE YOURSELF 承 ‘Her’          2017
# 29                                      BTS, THE BEST          2018
# 30                                              Proof          2017
# 31                              LOVE YOURSELF 承 ‘Her’          2017
# 32                                              Proof          2022
# 33                                              Proof          2014
# 34                                              Proof          2015
# 35  화양연화 Young Forever (The Most Beautiful Moment ...          2015
# 36  화양연화 Young Forever (The Most Beautiful Moment ...          2015
# 37                             LOVE YOURSELF 轉 ‘Tear’          2018
# 38                                SoundCloud Releases          2013
# 39                                 MAP OF THE SOUL: 7          2020
# 40  화양연화 Young Forever (The Most Beautiful Moment ...          2015
# 41  화양연화 Young Forever (The Most Beautiful Moment ...          2016
# 42                                              Proof          2018
# 43                    BTS WORLD (Original Soundtrack)          2019
# 44                                              Proof          2014
# 45                                                 BE          2020
# 46                                              Proof          2015
# 47  화양연화 Young Forever (The Most Beautiful Moment ...          2016
# 48                                              Proof          2016
# 49                                SoundCloud Releases          2017
#
#     Word Count
# 0          266
# 1          239
# 2          135
# 3          221
# 4          240
# 5           75
# 6           60
# 7           79
# 8          274
# 9           77
# 10          98
# 11         111
# 12         130
# 13          70
# 14         129
# 15         286
# 16         156
# 17         120
# 18         209
# 19         130
# 20          99
# 21          74
# 22         111
# 23         142
# 24         110
# 25          90
# 26          48
# 27          69
# 28          72
# 29         106
# 30         100
# 31         136
# 32         192
# 33          70
# 34         140
# 35          73
# 36         100
# 37          95
# 38          91
# 39         150
# 40         126
# 41          65
# 42         160
# 43         127
# 44          72
# 45          72
# 46          57
# 47         132
# 48          81
# 49          76

# %%
# Lista de palavras indesejadas presentes na discografia e não identificadas na etapa de tokenização
indesejadas = ['na','yeah']

# Remove as palavras indesejadas, e salva de volta como um texto longo
df['lyrics'] = df['lyrics'].apply(lambda x: ' '.join([palavra for palavra in x.split() if palavra not in (indesejadas)]))

# Une o dataframe em uma string longa/TextBlob
text = " ".join(twt for twt in df['lyrics'])
palavras = word_tokenize(text)

print("Existem {} palavras no dataset de letra.".format(len(palavras)))
print("Existem {} palavras únicas no dataset de letras.".format(len(set(palavras))))
# Out:
# Existem 30920 palavras no dataset de letra.
# Existem 5342 palavras únicas no dataset de letras.
