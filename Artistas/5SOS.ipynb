# %%
import os
import pandas as pd
import requests
import lyricsgenius
import csv

# Chamada de Requisição
api_key = "YOUR_API_KEY"
genius = lyricsgenius.Genius(api_key)

# Busca do artista na API
artist = genius.search_artist("5 Seconds Of Summer", max_songs=40)
# Out:
# Searching for songs by 5 Seconds Of Summer...
#
# Changing artist name to '5 Seconds of Summer'
# Song 1: "Youngblood"
# Song 2: "She Looks So Perfect"
# Song 3: "Teeth"
# Song 4: "Lie to Me"
# Song 5: "Valentine"
# Song 6: "Ghost of You"
# Song 7: "Wildflower"
# Song 8: "No Shame"
# Song 9: "Easier"
# Song 10: "Amnesia"
# Song 11: "Want You Back"
# Song 12: "Lover of Mine"
# Song 13: "Moving Along"
# Song 14: "Old Me"
# Song 15: "English Love Affair"
# Song 16: "Jet Black Heart"
# Song 17: "Babylon"
# Song 18: "Not in the Same Way"
# Song 19: "Best Years"
# Song 20: "She’s Kinda Hot"
# Song 21: "Red Desert"
# Song 22: "If Walls Could Talk"
# Song 23: "Broken Home"
# Song 24: "Outer Space / Carry On"
# Song 25: "High"
# Song 26: "Talk Fast"
# Song 27: "Invisible"
# Song 28: "Lonely Heart"
# Song 29: "Thin White Lies"
# Song 30: "Safety Pin"
# Song 31: "Why Won’t You Love Me"
# Song 32: "More"
# Song 33: "When You Walk Away"
# Song 34: "Best Friend"
# Song 35: "Vapor"
# Song 36: "Bad Omens"
# Song 37: "Empty Wallets"
# Song 38: "The Girl Who Cried Wolf"
# Song 39: "Permanent Vacation"
# Song 40: "Story of Another Us"
#
# Reached user-specified song limit (40).
# Done. Found 40 songs.

# %%
# Importando para um arquivo json
artist.save_lyrics()
# Out:
# Wrote Lyrics_5SecondsofSummer.json.

# %%
# Acessando as chaves principais dos dados contidos no arquivo JSON
data = json.load(open("Lyrics_5SecondsofSummer.json", "r"))
data.keys()
# Out:
# dict_keys(['alternate_names', 'api_path', 'description', 'facebook_name', 'header_image_url', 'id', 'image_url', 'instagram_name', 'is_meme_verified', 'is_verified', 'name', 'translation_artist', 'twitter_name', 'url', 'current_user_metadata', 'followers_count', 'iq', 'description_annotation', 'user', 'songs'])

# %%
# Carregando dados em um dataframe e examinando os dados dentro de 'songs'
df = pd.DataFrame(data['songs'])
df.keys()
# Out:
# Index(['annotation_count', 'api_path', 'artist_names', 'full_title',
#        'header_image_thumbnail_url', 'header_image_url', 'id',
#        'lyrics_owner_id', 'lyrics_state', 'path', 'primary_artist_names',
#        'pyongs_count', 'relationships_index_url', 'release_date_components',
#        'release_date_for_display',
#        'release_date_with_abbreviated_month_for_display',
#        'song_art_image_thumbnail_url', 'song_art_image_url', 'stats', 'title',
#        'title_with_featured', 'url', 'featured_artists', 'primary_artist',
#        'primary_artists', 'apple_music_id', 'apple_music_player_url',
#        'description', 'embed_content', 'language', 'recording_location',
#        'release_date', 'current_user_metadata', 'song_art_primary_color',
#        'song_art_secondary_color', 'song_art_text_color', 'album',
#        'custom_performances', 'description_annotation',
#        'lyrics_marked_complete_by', 'lyrics_marked_staff_approved_by', 'media',
#        'producer_artists', 'song_relationships', 'translation_songs',
#        'verified_annotations_by', 'verified_contributors',
#        'verified_lyrics_by', 'writer_artists', 'artist', 'lyrics'],
#       dtype='object')

# %%
# Selecionando os dados úteis em um novo dataframe
df_oficial = df[['title', 'lyrics', 'release_date']].copy()

# Classificando as músicas pelo álbum
df_oficial['Album'] = df['album'].apply(lambda x: x.get('name') if isinstance(x, dict) else None)

# Reseta o índice, se necessário
df_oficial.reset_index(drop=True, inplace=True)

# Convertendo a coluna 'release_date' para o formato de data
df_oficial['release_date'] = pd.to_datetime(df_oficial['release_date'], errors='coerce')

# Extraindo apenas o ano da coluna 'release_date' para armazenar na 'release_year'
df_oficial['release_year'] = df_oficial['release_date'].dt.year

# Exibindo o dataframe resultante
df_oficial
# Out:
#                       title  \
# 0                Youngblood
# 1      She Looks So Perfect
# 2                     Teeth
# 3                 Lie to Me
# 4                 Valentine
# 5              Ghost of You
# 6                Wildflower
# 7                  No Shame
# 8                    Easier
# 9                   Amnesia
# 10            Want You Back
# 11            Lover of Mine
# 12             Moving Along
# 13                   Old Me
# 14      English Love Affair
# 15          Jet Black Heart
# 16                  Babylon
# 17      Not in the Same Way
# 18               Best Years
# 19          She’s Kinda Hot
# 20               Red Desert
# 21      If Walls Could Talk
# 22              Broken Home
# 23   Outer Space / Carry On
# 24                     High
# 25                Talk Fast
# 26                Invisible
# 27             Lonely Heart
# 28          Thin White Lies
# 29               Safety Pin
# 30    Why Won’t You Love Me
# 31                     More
# 32       When You Walk Away
# 33              Best Friend
# 34                    Vapor
# 35                Bad Omens
# 36            Empty Wallets
# 37  The Girl Who Cried Wolf
# 38       Permanent Vacation
# 39      Story of Another Us
#
#                                                lyrics release_date  \
# 0   151 ContributorsTranslationsEspañolPortuguêsPo...   2018-04-12
# 1   71 ContributorsTranslationsČeskyРусский (Russi...   2014-02-21
# 2   95 ContributorsTranslationsУкраїнськаTürkçeفار...   2019-08-21
# 3   73 ContributorsTranslationsPolskiEspañolPortug...   2018-06-15
# 4   75 ContributorsTranslationsPolskiEspañolPortug...   2018-06-15
# 5   82 ContributorsTranslationsPolskiEspañolPortug...   2018-06-15
# 6   66 ContributorsTranslationsTürkçeEnglishWildfl...   2020-03-25
# 7   60 ContributorsTranslationsTürkçePortuguêsEngl...   2020-02-05
# 8   87 ContributorsTranslationsTürkçeEspañolفارسیE...   2019-05-23
# 9   75 ContributorsTranslationsPolskiAmnesia Lyric...   2014-07-15
# 10  102 ContributorsTranslationsPolskiEspañolPortu...   2018-02-23
# 11  53 ContributorsTranslationsTürkçeEspañolفارسیL...   2020-03-27
# 12  83 ContributorsTranslationsPolskiEspañolPortug...   2018-06-15
# 13  64 ContributorsTranslationsTürkçePortuguêsفارس...   2020-02-21
# 14  77 ContributorsTranslationsČeskyPolskiEspañolE...   2014-06-27
# 15  78 ContributorsTranslationsPortuguêsItalianoJe...   2015-12-17
# 16  93 ContributorsTranslationsPolskiEspañolPortug...   2018-06-15
# 17  60 ContributorsTranslationsEspañolTürkçeEnglis...   2020-03-27
# 18  52 ContributorsTranslationsTürkçeEnglishBest Y...   2020-03-27
# 19  77 ContributorsTranslationsPortuguêsShe’s Kind...   2015-07-17
# 20  53 ContributorsTranslationsTürkçePortuguêsفارس...   2020-03-27
# 21  56 ContributorsTranslationsPolskiEspañolPortug...   2018-06-15
# 22  66 ContributorsTranslationsTürkçePortuguêsBrok...   2015-10-23
# 23  40 ContributorsTranslationsPortuguêsOuter Spac...   2015-10-23
# 24  42 ContributorsTranslationsTürkçeEnglishHigh L...   2020-03-27
# 25  47 ContributorsTranslationsPolskiEspañolPortug...   2018-06-15
# 26  41 ContributorsInvisible LyricsTrack off Aussi...   2015-10-23
# 27  55 ContributorsTranslationsTürkçeفارسیLonely H...   2020-03-27
# 28  43 ContributorsTranslationsTürkçeEnglishThin W...   2020-03-27
# 29  51 ContributorsTranslationsPortuguêsSafety Pin...   2015-08-28
# 30  49 ContributorsTranslationsPolskiEspañolPortug...   2018-06-15
# 31  43 ContributorsTranslationsPolskiEspañolPortug...   2018-06-15
# 32  49 ContributorsTranslationsPolskiEspañolPortug...   2018-06-15
# 33  65 ContributorsTranslationsPolskiEspañolPortug...   2018-06-15
# 34  28 ContributorsTranslationsPortuguêsVapor Lyri...   2015-10-23
# 35  21 ContributorsTranslationsPortuguêsPolskiEspa...   2022-09-23
# 36  50 ContributorsTranslationsPolskiEspañolPortug...   2018-06-15
# 37  53 ContributorsTranslationsPortuguêsThe Girl W...   2015-08-28
# 38  56 ContributorsTranslationsPortuguêsPermanent ...   2015-10-23
# 39  38 ContributorsTranslationsPortuguêsStory of A...   2015-10-23
#
#                                         Album  release_year
# 0               Youngblood (Japanese Edition)          2018
# 1      5 Seconds of Summer (Japanese Edition)          2014
# 2                               CALM (Deluxe)          2019
# 3               Youngblood (Japanese Edition)          2018
# 4               Youngblood (Japanese Edition)          2018
# 5               Youngblood (Japanese Edition)          2018
# 6                               CALM (Deluxe)          2020
# 7                               CALM (Deluxe)          2020
# 8                               CALM (Deluxe)          2019
# 9      5 Seconds of Summer (Japanese Edition)          2014
# 10              Youngblood (Japanese Edition)          2018
# 11                              CALM (Deluxe)          2020
# 12              Youngblood (Japanese Edition)          2018
# 13                              CALM (Deluxe)          2020
# 14     5 Seconds of Summer (Japanese Edition)          2014
# 15  Sounds Good Feels Good (Japanese Edition)          2015
# 16              Youngblood (Japanese Edition)          2018
# 17                              CALM (Deluxe)          2020
# 18                              CALM (Deluxe)          2020
# 19  Sounds Good Feels Good (Japanese Edition)          2015
# 20                              CALM (Deluxe)          2020
# 21              Youngblood (Japanese Edition)          2018
# 22  Sounds Good Feels Good (Japanese Edition)          2015
# 23  Sounds Good Feels Good (Japanese Edition)          2015
# 24                              CALM (Deluxe)          2020
# 25              Youngblood (Japanese Edition)          2018
# 26  Sounds Good Feels Good (Japanese Edition)          2015
# 27                              CALM (Deluxe)          2020
# 28                              CALM (Deluxe)          2020
# 29  Sounds Good Feels Good (Japanese Edition)          2015
# 30              Youngblood (Japanese Edition)          2018
# 31              Youngblood (Japanese Edition)          2018
# 32              Youngblood (Japanese Edition)          2018
# 33              Youngblood (Japanese Edition)          2018
# 34  Sounds Good Feels Good (Japanese Edition)          2015
# 35                    5SOS5 (Japan Exclusive)          2022
# 36              Youngblood (Japanese Edition)          2018
# 37  Sounds Good Feels Good (Japanese Edition)          2015
# 38  Sounds Good Feels Good (Japanese Edition)          2015
# 39  Sounds Good Feels Good (Target Exclusive)          2015

# %%
import nltk
from nltk.corpus import stopwords
import re

# Define uma função para remover stopwords de um texto
def remove_stopwords(text):
    # Separa o texto em uma lista de palavras
    text = text.split(' ')
    # Filtra a lista, mantendo apenas as palavras que não estão na lista de stopwords em inglês
    text = [x for x in text if x not in stopwords.words('english')]
    # Junta a lista de palavras filtradas em uma única string e a retorna
    return ' '.join(text)

# Aplica a função de remoção de stopwords em cada linha da coluna 'lyrics' do dataframe
df_oficial.loc[:, 'lyrics'] = df_oficial.loc[:, 'lyrics'].apply(lambda x: remove_stopwords(x))

# Define uma função para remover pontuação do texto
def remove_ponctuation(text):
    # Usa uma expressão regular para manter apenas letras (maiúsculas e minúsculas) e junta as palavras em uma string
    return " ".join(re.findall("[a-zA-Z]+", text))

# Aplica a função de remoção de pontuação em cada linha da coluna 'lyrics' do dataframe
df_oficial.loc[:, 'lyrics'] = df_oficial.loc[:, 'lyrics'].apply(lambda x: remove_ponctuation(x))

# Define uma função para remover palavras com menos de 3 caracteres do texto
def remove_words_with_less_3(text):
    # Separa o texto em uma lista de palavras
    text = text.split(' ')
    # Filtra a lista, mantendo apenas as palavras com mais de 3 caracteres
    text = [x for x in text if len(x) > 3]
    # Junta a lista de palavras filtradas em uma única string e a retorna
    return ' '.join(text)

# Aplica a função de remoção de palavras curtas em cada linha da coluna 'lyrics' do dataframe
df_oficial.loc[:, 'lyrics'] = df_oficial.loc[:, 'lyrics'].apply(lambda x: remove_words_with_less_3(x))

# Converte todo o texto em letras minúsculas em cada linha da coluna 'lyrics' do dataframe
df_oficial.loc[:, 'lyrics'] = df_oficial.loc[:, 'lyrics'].apply(lambda x: x.lower())

# Cria uma nova coluna 'Word Count' no dataframe que conta o número de palavras em cada linha da coluna 'lyrics'
df_oficial['Word Count'] = df_oficial['lyrics'].apply(lambda x: len(x.split(' ')))

# Função para remover as palavras indesejadas
def remove_unwanted_words(text):
    words_to_remove = ["embed", "intro", "verse", "chorus", "outro", "instrumental"]
    pattern = r'\b(?:' + '|'.join(words_to_remove) + r')\b'
    return re.sub(pattern, '', text, flags=re.IGNORECASE)

# Aplicar a função na coluna de letras
df_oficial["lyrics"] = df_oficial["lyrics"].apply(remove_unwanted_words)

# Salvar o CSV atualizado
df_oficial.to_csv("5SOS.csv", index=False)

# %%
# Importando bibliotecas de manipulação e análise de dados
import pandas as pd  # Usado para manipulação de tabelas e dataframes
import numpy as np   # Usado para operações matemáticas e arrays numéricos

# Biblioteca de NLP (Processamento de Linguagem Natural)
from nltk.tokenize import word_tokenize  # Quebra textos em palavras (tokens)

# Baixando recursos da biblioteca NLTK
import nltk
nltk.download('punkt_tab')  # Tokenizador de pontuação/tabulação
nltk.download('vader_lexicon')  # Léxico para análise de sentimentos com VADER (análise de sentimentos)
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\Ryan\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\Ryan\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
# Leitura do Arquivo
df_oficial=pd.read_csv("5SOS.csv")

# Remove a coluna 'release_date'
df_oficial = df_oficial.drop(columns=['release_date'])

# Visualização do Dataframe
df_oficial
# Out:
#                       title  \
# 0                Youngblood
# 1      She Looks So Perfect
# 2                     Teeth
# 3                 Lie to Me
# 4                 Valentine
# 5              Ghost of You
# 6                Wildflower
# 7                  No Shame
# 8                    Easier
# 9                   Amnesia
# 10            Want You Back
# 11            Lover of Mine
# 12             Moving Along
# 13                   Old Me
# 14      English Love Affair
# 15          Jet Black Heart
# 16                  Babylon
# 17      Not in the Same Way
# 18               Best Years
# 19          She’s Kinda Hot
# 20               Red Desert
# 21      If Walls Could Talk
# 22              Broken Home
# 23   Outer Space / Carry On
# 24                     High
# 25                Talk Fast
# 26                Invisible
# 27             Lonely Heart
# 28          Thin White Lies
# 29               Safety Pin
# 30    Why Won’t You Love Me
# 31                     More
# 32       When You Walk Away
# 33              Best Friend
# 34                    Vapor
# 35                Bad Omens
# 36            Empty Wallets
# 37  The Girl Who Cried Wolf
# 38       Permanent Vacation
# 39      Story of Another Us
#
#                                                lyrics  \
# 0   contributorstranslationsespa olportugu spolski...
# 1   contributorstranslations esky russian polskies...
# 2   contributorstranslations teeth lyrics teeth ba...
# 3   contributorstranslationspolskiespa olportugu s...
# 4   contributorstranslationspolskiespa olportugu s...
# 5   contributorstranslationspolskiespa olportugu s...
# 6   contributorstranslationst eenglishwildflower l...
# 7   contributorstranslationst eportugu senglishno ...
# 8   contributorstranslationst eespa easier lyrics ...
# 9   contributorstranslationspolskiamnesia lyrics a...
# 10  contributorstranslationspolskiespa olportugu s...
# 11  contributorstranslationst eespa lover mine lyr...
# 12  contributorstranslationspolskiespa olportugu s...
# 13  contributorstranslationst eportugu lyrics thir...
# 14  contributorstranslations eskypolskiespa olengl...
# 15  contributorstranslationsportugu sitalianojet b...
# 16  contributorstranslationspolskiespa olportugu s...
# 17  contributorstranslationsespa eenglishnot same ...
# 18  contributorstranslationst eenglishbest years l...
# 19  contributorstranslationsportugu sshe kinda lyr...
# 20  contributorstranslationst eportugu desert lyri...
# 21  contributorstranslationspolskiespa olportugu w...
# 22  contributorstranslationst eportugu sbroken hom...
# 23  contributorstranslationsportugu souter space c...
# 24  contributorstranslationst eenglishhigh lyrics ...
# 25  contributorstranslationspolskiespa olportugu s...
# 26  contributorsinvisible lyricstrack aussie band ...
# 27  contributorstranslationst lonely heart lyrics ...
# 28  contributorstranslationst eenglishthin white l...
# 29  contributorstranslationsportugu ssafety lyrics...
# 30  contributorstranslationspolskiespa olportugu s...
# 31  contributorstranslationspolskiespa olportugu s...
# 32  contributorstranslationspolskiespa olportugu s...
# 33  contributorstranslationspolskiespa olportugu s...
# 34  contributorstranslationsportugu svapor lyrics ...
# 35  contributorstranslationsportugu spolskiespa eb...
# 36  contributorstranslationspolskiespa olportugu s...
# 37  contributorstranslationsportugu sthe girl crie...
# 38  contributorstranslationsportugu spermanent vac...
# 39  contributorstranslationsportugu sstory another...
#
#                                         Album  release_year  Word Count
# 0               Youngblood (Japanese Edition)          2018         213
# 1      5 Seconds of Summer (Japanese Edition)          2014         159
# 2                               CALM (Deluxe)          2019         247
# 3               Youngblood (Japanese Edition)          2018         114
# 4               Youngblood (Japanese Edition)          2018         150
# 5               Youngblood (Japanese Edition)          2018         124
# 6                               CALM (Deluxe)          2020         200
# 7                               CALM (Deluxe)          2020         173
# 8                               CALM (Deluxe)          2019         211
# 9      5 Seconds of Summer (Japanese Edition)          2014         243
# 10              Youngblood (Japanese Edition)          2018         235
# 11                              CALM (Deluxe)          2020         178
# 12              Youngblood (Japanese Edition)          2018         219
# 13                              CALM (Deluxe)          2020         257
# 14     5 Seconds of Summer (Japanese Edition)          2014         227
# 15  Sounds Good Feels Good (Japanese Edition)          2015         179
# 16              Youngblood (Japanese Edition)          2018         207
# 17                              CALM (Deluxe)          2020         251
# 18                              CALM (Deluxe)          2020         150
# 19  Sounds Good Feels Good (Japanese Edition)          2015         193
# 20                              CALM (Deluxe)          2020         144
# 21              Youngblood (Japanese Edition)          2018         198
# 22  Sounds Good Feels Good (Japanese Edition)          2015         208
# 23  Sounds Good Feels Good (Japanese Edition)          2015         298
# 24                              CALM (Deluxe)          2020         159
# 25              Youngblood (Japanese Edition)          2018         192
# 26  Sounds Good Feels Good (Japanese Edition)          2015         110
# 27                              CALM (Deluxe)          2020         177
# 28                              CALM (Deluxe)          2020         239
# 29  Sounds Good Feels Good (Japanese Edition)          2015         174
# 30              Youngblood (Japanese Edition)          2018         135
# 31              Youngblood (Japanese Edition)          2018         175
# 32              Youngblood (Japanese Edition)          2018         169
# 33              Youngblood (Japanese Edition)          2018         160
# 34  Sounds Good Feels Good (Japanese Edition)          2015         189
# 35                    5SOS5 (Japan Exclusive)          2022         153
# 36              Youngblood (Japanese Edition)          2018         171
# 37  Sounds Good Feels Good (Japanese Edition)          2015         181
# 38  Sounds Good Feels Good (Japanese Edition)          2015         194
# 39  Sounds Good Feels Good (Target Exclusive)          2015         228

# %%
# Lista de palavras indesejadas presentes na discografia e não identificadas na etapa de tokenização
indesejadas = ['na','yeah']

# Remove as palavras indesejadas, e salva de volta como um texto longo
df['lyrics'] = df['lyrics'].apply(lambda x: ' '.join([palavra for palavra in x.split() if palavra not in (indesejadas)]))

# Une o dataframe em uma string longa/TextBlob
text = " ".join(twt for twt in df['lyrics'])
palavras = word_tokenize(text)

print("Existem {} palavras no dataset de letra.".format(len(palavras)))
print("Existem {} palavras únicas no dataset de letras.".format(len(set(palavras))))
# Out:
# Existem 2301 palavras no dataset de letra.
# Existem 453 palavras únicas no dataset de letras.
