# %%
import os
import pandas as pd
import requests
import lyricsgenius
import csv

# Chamada de Requisição
api_key = "YOUR_API_KEY"
genius = lyricsgenius.Genius(api_key)

# Busca do artista na API
artist = genius.search_artist("Tove Lo", max_songs=35)
# Out:
# Searching for songs by Tove Lo...
#
# Song 1: "Habits (Stay High)"
# Song 2: "Talking Body"
# Song 3: "Cool Girl"
# Song 4: "Glad He’s Gone"
# Song 5: "​disco tits"
# Song 6: "​bitches"
# Song 7: "Habits (Stay High) [Hippie Sabotage Remix]"
# Song 8: "True Disaster"
# Song 9: "Moments"
# Song 10: "​hey you got drugs?"
# Song 11: "Influence"
# Song 12: "Sweettalk my Heart"
# Song 13: "​shedontknowbutsheknows"
# Song 14: "Lady Wood"
# Song 15: "Are U gonna tell her?"
# Song 16: "Grapefruit"
# Song 17: "Bikini Porn"
# Song 18: "2 Die 4"
# Song 19: "Thousand Miles"
# Song 20: "How Long"
# Song 21: "Lies in the Dark"
# Song 22: "​stranger"
# Song 23: "​shivering gold"
# Song 24: "Scream My Name"
# Song 25: "Bad as the Boys"
# Song 26: "Really don’t like u"
# Song 27: "Don’t Talk About It"
# Song 28: "No One Dies From Love"
# Song 29: "Mateo"
# Song 30: "Not on Drugs"
# Song 31: "Borderline"
# Song 32: "​dont ask dont tell"
# Song 33: "​cycles"
# Song 34: "​struggle"
# Song 35: "​9th of october"
#
# Reached user-specified song limit (35).
# Done. Found 35 songs.

# %%
# Importando para um arquivo json
artist.save_lyrics()
# Out:
# Wrote Lyrics_ToveLo.json.

# %%
# Acessando as chaves principais dos dados contidos no arquivo JSON
data = json.load(open("Lyrics_ToveLo.json", "r"))
data.keys()
# Out:
# dict_keys(['alternate_names', 'api_path', 'description', 'facebook_name', 'header_image_url', 'id', 'image_url', 'instagram_name', 'is_meme_verified', 'is_verified', 'name', 'translation_artist', 'twitter_name', 'url', 'current_user_metadata', 'followers_count', 'iq', 'description_annotation', 'user', 'songs'])

# %%
# Carregando dados em um dataframe e examinando os dados dentro de 'songs'
df = pd.DataFrame(data['songs'])
df.keys()
# Out:
# Index(['annotation_count', 'api_path', 'artist_names', 'full_title',
#        'header_image_thumbnail_url', 'header_image_url', 'id',
#        'lyrics_owner_id', 'lyrics_state', 'path', 'primary_artist_names',
#        'pyongs_count', 'relationships_index_url', 'release_date_components',
#        'release_date_for_display',
#        'release_date_with_abbreviated_month_for_display',
#        'song_art_image_thumbnail_url', 'song_art_image_url', 'stats', 'title',
#        'title_with_featured', 'url', 'featured_artists', 'primary_artist',
#        'primary_artists', 'apple_music_id', 'apple_music_player_url',
#        'description', 'embed_content', 'language', 'recording_location',
#        'release_date', 'current_user_metadata', 'song_art_primary_color',
#        'song_art_secondary_color', 'song_art_text_color', 'album',
#        'custom_performances', 'description_annotation',
#        'lyrics_marked_complete_by', 'lyrics_marked_staff_approved_by', 'media',
#        'producer_artists', 'song_relationships', 'translation_songs',
#        'verified_annotations_by', 'verified_contributors',
#        'verified_lyrics_by', 'writer_artists', 'artist', 'lyrics'],
#       dtype='object')

# %%
# Selecionando os dados úteis em um novo dataframe
df_oficial = df[['title', 'lyrics', 'release_date']].copy()

# Classificando as músicas pelo álbum
df_oficial['Album'] = df['album'].apply(lambda x: x.get('name') if isinstance(x, dict) else None)

# Reseta o índice, se necessário
df_oficial.reset_index(drop=True, inplace=True)

# Convertendo a coluna 'release_date' para o formato de data
df_oficial['release_date'] = pd.to_datetime(df_oficial['release_date'], errors='coerce')

# Extraindo apenas o ano da coluna 'release_date' para armazenar na 'release_year'
df_oficial['release_year'] = df_oficial['release_date'].dt.year

# Exibindo o dataframe resultante
df_oficial
# Out:
#                                          title  \
# 0                           Habits (Stay High)
# 1                                 Talking Body
# 2                                    Cool Girl
# 3                               Glad He’s Gone
# 4                                  ​disco tits
# 5                                     ​bitches
# 6   Habits (Stay High) [Hippie Sabotage Remix]
# 7                                True Disaster
# 8                                      Moments
# 9                          ​hey you got drugs?
# 10                                   Influence
# 11                          Sweettalk my Heart
# 12                     ​shedontknowbutsheknows
# 13                                   Lady Wood
# 14                       Are U gonna tell her?
# 15                                  Grapefruit
# 16                                 Bikini Porn
# 17                                     2 Die 4
# 18                              Thousand Miles
# 19                                    How Long
# 20                            Lies in the Dark
# 21                                   ​stranger
# 22                             ​shivering gold
# 23                              Scream My Name
# 24                             Bad as the Boys
# 25                         Really don’t like u
# 26                         Don’t Talk About It
# 27                       No One Dies From Love
# 28                                       Mateo
# 29                                Not on Drugs
# 30                                  Borderline
# 31                         ​dont ask dont tell
# 32                                     ​cycles
# 33                                   ​struggle
# 34                             ​9th of october
#
#                                                lyrics release_date  \
# 0   108 ContributorsTranslationsPortuguêsDeutschPo...   2013-03-15
# 1   57 ContributorsTalking Body Lyrics“Talking Bod...   2015-01-13
# 2   72 ContributorsCool Girl Lyrics“"Cool Girl” is...   2016-08-04
# 3   67 ContributorsTranslationsEspañolFrançaisGlad...   2019-05-31
# 4   68 ContributorsTranslationsPolski​disco tits L...   2017-09-07
# 5   61 ContributorsTranslationsPolski​bitches Lyri...   2017-11-17
# 6   38 ContributorsTranslationsPolskiHabits (Stay ...   2014-02-25
# 7   41 ContributorsTrue Disaster LyricsOn the 14th...   2016-10-14
# 8   34 ContributorsMoments Lyrics“Moments” is the ...   2014-09-24
# 9   54 ContributorsTranslationsPolski​hey you got ...   2017-11-17
# 10  42 ContributorsInfluence LyricsTove Lo initial...   2016-09-09
# 11  48 ContributorsTranslationsEspañolFrançaisTürk...   2019-09-18
# 12  45 ContributorsTranslationsPolski​shedontknowb...   2017-11-17
# 13  41 ContributorsLady Wood Lyrics“Lady Wood” is ...   2016-10-28
# 14  63 ContributorsTranslationsPolskiPortuguêsFran...   2019-09-20
# 15  39 ContributorsTranslationsFrançaisPortuguêsEs...   2022-10-12
# 16  51 ContributorsTranslationsPortuguêsEspañolPol...   2020-01-15
# 17  35 ContributorsTranslationsPolskisrpskiEspañol...   2022-07-27
# 18  27 ContributorsThousand Miles Lyrics“Thousand ...   2014-09-24
# 19  43 ContributorsTranslationsPortuguêsFrançaisPo...   2022-01-26
# 20  36 ContributorsLies in the Dark Lyrics“Lies in...   2017-02-09
# 21  44 ContributorsTranslationsPolski​stranger Lyr...   2017-11-17
# 22  37 ContributorsTranslationsPolski​shivering go...   2017-11-17
# 23  27 ContributorsScream My Name LyricsThis song ...   2014-11-17
# 24  37 ContributorsTranslationsEspañolFrançaisNede...   2019-08-02
# 25  43 ContributorsTranslationsFrançaisReally don’...   2019-09-06
# 26  37 ContributorsDon’t Talk About It Lyrics“Don’...   2016-10-28
# 27  33 ContributorsTranslationsPortuguêsEspañolFra...   2022-05-03
# 28  36 ContributorsTranslationsEspañolFrançaisMate...   2019-09-20
# 29  40 ContributorsTranslationsPolskiFrançaisNot o...   2014-02-24
# 30  28 ContributorsTranslationsPolskiFrançaisBorde...   2023-02-10
# 31  30 ContributorsTranslationsPolski​dont ask don...   2017-11-17
# 32  28 ContributorsTranslationsPolski​cycles Lyric...   2017-11-17
# 33  35 ContributorsTranslationsPolski​struggle Lyr...   2017-11-17
# 34  27 ContributorsTranslationsPolski​9th of octob...   2017-11-17
#
#                                                 Album  release_year
# 0                              Queen of the Clouds: X          2013
# 1                              Queen of the Clouds: X          2015
# 2                               Lady Wood / Blue Lips          2016
# 3                 Sunshine Kitty (Paw Prints Edition)          2019
# 4                               Lady Wood / Blue Lips          2017
# 5                               Lady Wood / Blue Lips          2017
# 6                              Queen of the Clouds: X          2014
# 7                               Lady Wood / Blue Lips          2016
# 8                              Queen of the Clouds: X          2014
# 9                               Lady Wood / Blue Lips          2017
# 10                              Lady Wood / Blue Lips          2016
# 11                Sunshine Kitty (Paw Prints Edition)          2019
# 12                              Lady Wood / Blue Lips          2017
# 13                              Lady Wood / Blue Lips          2016
# 14                Sunshine Kitty (Paw Prints Edition)          2019
# 15                          Dirt Femme (Extended Cut)          2022
# 16                Sunshine Kitty (Paw Prints Edition)          2020
# 17                          Dirt Femme (Extended Cut)          2022
# 18                             Queen of the Clouds: X          2014
# 19                          Dirt Femme (Extended Cut)          2022
# 20  Fifty Shades Darker (Original Motion Picture S...          2017
# 21                              Lady Wood / Blue Lips          2017
# 22                              Lady Wood / Blue Lips          2017
# 23            Queen of the Clouds (Blueprint Edition)          2014
# 24                Sunshine Kitty (Paw Prints Edition)          2019
# 25                Sunshine Kitty (Paw Prints Edition)          2019
# 26                              Lady Wood / Blue Lips          2016
# 27                          Dirt Femme (Extended Cut)          2022
# 28                Sunshine Kitty (Paw Prints Edition)          2019
# 29                             Queen of the Clouds: X          2014
# 30                          Dirt Femme (Extended Cut)          2023
# 31                              Lady Wood / Blue Lips          2017
# 32                              Lady Wood / Blue Lips          2017
# 33                              Lady Wood / Blue Lips          2017
# 34                              Lady Wood / Blue Lips          2017

# %%
import nltk
from nltk.corpus import stopwords
import re

# Define uma função para remover stopwords de um texto
def remove_stopwords(text):
    # Separa o texto em uma lista de palavras
    text = text.split(' ')
    # Filtra a lista, mantendo apenas as palavras que não estão na lista de stopwords em inglês
    text = [x for x in text if x not in stopwords.words('english')]
    # Junta a lista de palavras filtradas em uma única string e a retorna
    return ' '.join(text)

# Aplica a função de remoção de stopwords em cada linha da coluna 'lyrics' do dataframe
df_oficial.loc[:, 'lyrics'] = df_oficial.loc[:, 'lyrics'].apply(lambda x: remove_stopwords(x))

# Define uma função para remover pontuação do texto
def remove_ponctuation(text):
    # Usa uma expressão regular para manter apenas letras (maiúsculas e minúsculas) e junta as palavras em uma string
    return " ".join(re.findall("[a-zA-Z]+", text))

# Aplica a função de remoção de pontuação em cada linha da coluna 'lyrics' do dataframe
df_oficial.loc[:, 'lyrics'] = df_oficial.loc[:, 'lyrics'].apply(lambda x: remove_ponctuation(x))

# Define uma função para remover palavras com menos de 3 caracteres do texto
def remove_words_with_less_3(text):
    # Separa o texto em uma lista de palavras
    text = text.split(' ')
    # Filtra a lista, mantendo apenas as palavras com mais de 3 caracteres
    text = [x for x in text if len(x) > 3]
    # Junta a lista de palavras filtradas em uma única string e a retorna
    return ' '.join(text)

# Aplica a função de remoção de palavras curtas em cada linha da coluna 'lyrics' do dataframe
df_oficial.loc[:, 'lyrics'] = df_oficial.loc[:, 'lyrics'].apply(lambda x: remove_words_with_less_3(x))

# Converte todo o texto em letras minúsculas em cada linha da coluna 'lyrics' do dataframe
df_oficial.loc[:, 'lyrics'] = df_oficial.loc[:, 'lyrics'].apply(lambda x: x.lower())

# Cria uma nova coluna 'Word Count' no dataframe que conta o número de palavras em cada linha da coluna 'lyrics'
df_oficial['Word Count'] = df_oficial['lyrics'].apply(lambda x: len(x.split(' ')))

# Função para remover as palavras indesejadas
def remove_unwanted_words(text):
    words_to_remove = ["embed", "intro", "verse", "chorus", "outro", "instrumental"]
    pattern = r'\b(?:' + '|'.join(words_to_remove) + r')\b'
    return re.sub(pattern, '', text, flags=re.IGNORECASE)

# Aplicar a função na coluna de letras
df_oficial["lyrics"] = df_oficial["lyrics"].apply(remove_unwanted_words)

# Salvar o CSV atualizado
df_oficial.to_csv("ToveLo.csv", index=False)

# %%
# Importando bibliotecas de manipulação e análise de dados
import pandas as pd  # Usado para manipulação de tabelas e dataframes
import numpy as np   # Usado para operações matemáticas e arrays numéricos

# Biblioteca de NLP (Processamento de Linguagem Natural)
from nltk.tokenize import word_tokenize  # Quebra textos em palavras (tokens)

# Baixando recursos da biblioteca NLTK
import nltk
nltk.download('punkt_tab')  # Tokenizador de pontuação/tabulação
nltk.download('vader_lexicon')  # Léxico para análise de sentimentos com VADER (análise de sentimentos)
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\Ryan\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\Ryan\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
# Leitura do Arquivo
df_oficial=pd.read_csv("ToveLo.csv")

# Remove a coluna 'release_date'
df_oficial = df_oficial.drop(columns=['release_date'])

# Visualização do Dataframe
df_oficial
# Out:
#                                          title  \
# 0                           Habits (Stay High)
# 1                                 Talking Body
# 2                                    Cool Girl
# 3                               Glad He’s Gone
# 4                                  ​disco tits
# 5                                     ​bitches
# 6   Habits (Stay High) [Hippie Sabotage Remix]
# 7                                True Disaster
# 8                                      Moments
# 9                          ​hey you got drugs?
# 10                                   Influence
# 11                          Sweettalk my Heart
# 12                     ​shedontknowbutsheknows
# 13                                   Lady Wood
# 14                       Are U gonna tell her?
# 15                                  Grapefruit
# 16                                 Bikini Porn
# 17                                     2 Die 4
# 18                              Thousand Miles
# 19                                    How Long
# 20                            Lies in the Dark
# 21                                   ​stranger
# 22                             ​shivering gold
# 23                              Scream My Name
# 24                             Bad as the Boys
# 25                         Really don’t like u
# 26                         Don’t Talk About It
# 27                       No One Dies From Love
# 28                                       Mateo
# 29                                Not on Drugs
# 30                                  Borderline
# 31                         ​dont ask dont tell
# 32                                     ​cycles
# 33                                   ​struggle
# 34                             ​9th of october
#
#                                                lyrics  \
# 0   contributorstranslationsportugu sdeutschpolski...
# 1   contributorstalking body lyrics talking body s...
# 2   contributorscool girl lyrics cool girl electro...
# 3   contributorstranslationsespa olfran aisglad go...
# 4   contributorstranslationspolski disco tits lyri...
# 5   contributorstranslationspolski bitches lyrics ...
# 6   contributorstranslationspolskihabits stay high...
# 7   contributorstrue disaster lyricson october tru...
# 8   contributorsmoments lyrics moments third offic...
# 9   contributorstranslationspolski drugs lyrics dr...
# 10  contributorsinfluence lyricstove initially upl...
# 11  contributorstranslationsespa olfran aist eswee...
# 12  contributorstranslationspolski shedontknowbuts...
# 13  contributorslady wood lyrics lady wood title t...
# 14  contributorstranslationspolskiportugu sfran ai...
# 15  contributorstranslationsfran aisportugu sespa ...
# 16  contributorstranslationsportugu sespa olpolski...
# 17  contributorstranslationspolskisrpskiespa olpor...
# 18  contributorsthousand miles lyrics thousand mil...
# 19  contributorstranslationsportugu sfran aispolsk...
# 20  contributorslies dark lyrics lies dark tove se...
# 21  contributorstranslationspolski stranger lyrics...
# 22  contributorstranslationspolski shivering gold ...
# 23  contributorsscream name lyricsthis song origin...
# 24  contributorstranslationsespa olfran aisnederla...
# 25  contributorstranslationsfran aisreally like ly...
# 26  contributorsdon talk about lyrics talk about t...
# 27  contributorstranslationsportugu sespa olfran a...
# 28  contributorstranslationsespa olfran aismateo l...
# 29  contributorstranslationspolskifran aisnot drug...
# 30  contributorstranslationspolskifran aisborderli...
# 31  contributorstranslationspolski dont dont tell ...
# 32  contributorstranslationspolski cycles lyrics c...
# 33  contributorstranslationspolski struggle lyrics...
# 34  contributorstranslationspolski october lyrics ...
#
#                                                 Album  release_year  \
# 0                              Queen of the Clouds: X          2013
# 1                              Queen of the Clouds: X          2015
# 2                               Lady Wood / Blue Lips          2016
# 3                 Sunshine Kitty (Paw Prints Edition)          2019
# 4                               Lady Wood / Blue Lips          2017
# 5                               Lady Wood / Blue Lips          2017
# 6                              Queen of the Clouds: X          2014
# 7                               Lady Wood / Blue Lips          2016
# 8                              Queen of the Clouds: X          2014
# 9                               Lady Wood / Blue Lips          2017
# 10                              Lady Wood / Blue Lips          2016
# 11                Sunshine Kitty (Paw Prints Edition)          2019
# 12                              Lady Wood / Blue Lips          2017
# 13                              Lady Wood / Blue Lips          2016
# 14                Sunshine Kitty (Paw Prints Edition)          2019
# 15                          Dirt Femme (Extended Cut)          2022
# 16                Sunshine Kitty (Paw Prints Edition)          2020
# 17                          Dirt Femme (Extended Cut)          2022
# 18                             Queen of the Clouds: X          2014
# 19                          Dirt Femme (Extended Cut)          2022
# 20  Fifty Shades Darker (Original Motion Picture S...          2017
# 21                              Lady Wood / Blue Lips          2017
# 22                              Lady Wood / Blue Lips          2017
# 23            Queen of the Clouds (Blueprint Edition)          2014
# 24                Sunshine Kitty (Paw Prints Edition)          2019
# 25                Sunshine Kitty (Paw Prints Edition)          2019
# 26                              Lady Wood / Blue Lips          2016
# 27                          Dirt Femme (Extended Cut)          2022
# 28                Sunshine Kitty (Paw Prints Edition)          2019
# 29                             Queen of the Clouds: X          2014
# 30                          Dirt Femme (Extended Cut)          2023
# 31                              Lady Wood / Blue Lips          2017
# 32                              Lady Wood / Blue Lips          2017
# 33                              Lady Wood / Blue Lips          2017
# 34                              Lady Wood / Blue Lips          2017
#
#     Word Count
# 0          173
# 1          164
# 2          155
# 3          258
# 4          209
# 5          154
# 6          165
# 7          198
# 8          150
# 9          250
# 10         248
# 11         194
# 12         149
# 13         143
# 14         233
# 15         226
# 16         122
# 17         151
# 18         194
# 19         182
# 20         203
# 21         132
# 22         209
# 23         173
# 24         178
# 25         218
# 26         241
# 27         161
# 28         158
# 29         137
# 30         230
# 31         163
# 32         175
# 33         162
# 34         224

# %%
# Lista de palavras indesejadas presentes na discografia e não identificadas na etapa de tokenização
indesejadas = ['na','yeah']

# Remove as palavras indesejadas, e salva de volta como um texto longo
df['lyrics'] = df['lyrics'].apply(lambda x: ' '.join([palavra for palavra in x.split() if palavra not in (indesejadas)]))

# Une o dataframe em uma string longa/TextBlob
text = " ".join(twt for twt in df['lyrics'])
palavras = word_tokenize(text)

print("Existem {} palavras no dataset de letra.".format(len(palavras)))
print("Existem {} palavras únicas no dataset de letras.".format(len(set(palavras))))
# Out:
# Existem 18883 palavras no dataset de letra.
# Existem 1728 palavras únicas no dataset de letras.
